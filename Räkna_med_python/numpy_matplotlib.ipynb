# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.linspace(0,10,2)
y = 3*x+1

plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("y = 3x+1")
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
10*np.linspace(10,100,10)
# Out:
# array([ 100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,  900.,
#        1000.])

# %%
[10,20,30,40]*3
# Out:
# [10, 20, 30, 40, 10, 20, 30, 40, 10, 20, 30, 40]
